# %%
from data_processing import load_data, load_data_from_folder
from visualization import visualize_fft, visualize_stft, set_font_size

# %%
df_ok = load_data_from_folder('./data/OK/')
print(df_ok)
# Out:
#    id                                                acc  sampling_rate  \
# 0  97  [[0.05319692307692307], [0.08866153846153846],...          48000
#
#     label  label_number
# 0  normal             0

# %%
df_ng = load_data_from_folder('./data/NG')
print(df_ng)
# Out:
#     id                                                acc  sampling_rate  \
# 0  105  [[-0.08300435129740519], [-0.19573433133732535...          48000
# 1  118  [[-0.0027613972055888225], [-0.096324031936127...          48000
# 2  130  [[0.008527844311377245], [0.4235496007984032],...          48000
# 3  144  [[-0.16933862275449102], [-0.04060878243512974...          48000
# 4  156  [[-0.1020092614770459], [0.06724814371257484],...          48000
#
#       label  label_number
# 0  abnormal             1
# 1  abnormal             1
# 2  abnormal             1
# 3  abnormal             1
# 4  abnormal             1

# %%
set_font_size(30)

# %%
visualize_fft(df_ok, idx=0, rows=1, cols=1)
visualize_stft(df_ok, idx=0, rows=1, cols=1)

# %%
visualize_fft(df_ng)
visualize_stft(df_ng)
